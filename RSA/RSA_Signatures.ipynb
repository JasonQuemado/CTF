# %%
import hashlib
from Crypto.Util.number import bytes_to_long

flag = "crypto{Immut4ble_m3ssag1ng}"
N = ...
d = ...

def hasher(d,n):
    hflag = hashlib.sha256(b'crypto{Immut4ble_m3ssag1ng}').hexdigest()
    print("Este es el hash en hex del string")
    print(hflag) 
    hflag = int(hflag,16)
    print("Este es el hash en enteros del string")
    print(hflag)
    hflag = pow(hflag,d,n)
    print("Este es el hash encriptado")
    print(hflag)

hasher(d,N)
# Out:
# Este es el hash en hex del string
# 99b4c7bb814cc630c4199e4814ffed85a835f64ffc82aadaa6388d9df9aeb2cb
# Este es el hash en enteros del string
# 69523276807549773371481917516452638375664281433555793080445569568100703974091
# Este es el hash encriptado
# ...
